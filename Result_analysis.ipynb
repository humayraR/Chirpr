# %% [markdown]
# <a href="https://colab.research.google.com/github/humayraR/Chirpr/blob/master/Result_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Fairness
#ftu
# eps = [0.1,1,10] # 1 -> orig, 2 -> mod
eps = ["eps0.1", "eps1", "eps10"]
dp = [0.1479, 0.0204, 0.0119]
dp2 = [0.0004, 0.0009, 0.0047] #orig vs mod


dp_fact_ftu = [0.0016, 0.0012, 0.0239]
dp_fact_ftu2 = [0.0002, 0.0, 0.077]
dp_fact_dp = [0.0030, 0.1182, 0.0808]
dp_fact_dp2 = [0,0.0197, 0.0003]
dp_fact_cf = [0.0054, 0.0062,0.0007]
dp_fact_cf2 =  [0.0024, 0.00003, 0.0]

dp_decaf_ftu = [0.0009, 0.0005, 0.0001] # all 0 on 2 -> mod(synth, orig)
dp_decaf_dp = [0.0002, 0.0001, 0.0001]
dp_decaf_cf = [0.0012, 0.0001, 0.0006]


# plot lines
y_label = "Fairness Through Unawareness(FTU)"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %%
  #dp
dp = [0.0825, 0.0335, 0.0005]
dp2 = [0.00107, -0.0018,-0.0046]
dp_fact_ftu = [0.0014, 0.0032, 0.0252]
dp_fact_ftu2 = [-0.0009, 0, 0.0002]
dp_fact_dp = [0.0029, 0.1263, 0.1367]
dp_fact_dp2 = [0,-0.0105, 0.0002]
dp_fact_cf = [0.0057, 0.0076, 0.0022]
dp_fact_cf2 = [0.0024, 0.0, 0.0]

dp_decaf_ftu = [0.0034, 0.0002, 0.0008]
dp_decaf_dp = [-0.00002, 0.0001, -0.0005]
dp_decaf_cf = [0.0027, 0.0001, 0.00068]

# plot lines
y_label = "Demographic Parity (DP)"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %% [markdown]
# **Performance**

# %%
#Precision
dp = [0.6435, 0.7106, 0.7064]

dp_fact_ftu = [0.2553, 0.3679, 0.2753]
dp_fact_dp = [0.2259, 0.2239, 0.2609]
dp_fact_cf = [0.4099, 0.6464, 0.5444]

dp_decaf_ftu = [0.9456, 0.7661, 0.8899]
dp_decaf_dp = [0.9447, 0.6404, 0.7980]
dp_decaf_cf = [0.8051, 0.8563, 0.7980]

# plot lines
y_label = "Precision"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %%
#Recall
dp = [0.1941, 0.5155, 0.6448]

dp_fact_ftu = [0.3214, 0.5307, 0.3095]
dp_fact_dp = [0.5419, 0.5562, 0.6738]
dp_fact_cf = [0.6007, 0.5546, 0.5624]

dp_decaf_ftu = [0.2077, 0.5483, 0.080]
dp_decaf_dp = [0.3559, 0.0985, 0.5659]
dp_decaf_cf = [0.3351, 0.7816, 0.5659]

# plot lines
y_label = "Recall"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %% [markdown]
# **Utility**

# %%
#linear model syn id
dp = [0.5432, 0.5715, 0.5776]

dp_fact_ftu = [0.5086, 0.4062, 0.5800]
dp_fact_dp = [0.4824, 0.5705, 0.3832]
dp_fact_cf = [0.5198, 0.3448, 0.4769]

dp_decaf_ftu = [0,0,0]
dp_decaf_dp = [0,0,0]
dp_decaf_cf = [0,0,0]

y_label = "Linear Model ID"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
# plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
# plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
# plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %%
#mlp_syn id
dp = [0.6638, 0.6640, 0.6421]

dp_fact_ftu = [0.6299, 0.6689, 0.6781]
dp_fact_dp = [0.6377, 0.6518, 0.6318]
dp_fact_cf = [0.6567, 0.6305, 0.6069]

dp_decaf_ftu = [0,0,0]
dp_decaf_dp = [0,0,0]
dp_decaf_cf = [0,0,0]

y_label = "Multilayer Perceptron(MLP) ID"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
# plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
# plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
# plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %%
#detection mlp
dp = [0.9993, 0.9976, 0.9988]

dp_fact_ftu = [0.9990, 0.9993, 0.9996]
dp_fact_dp = [0.9995, 0.9986, 0.9985]
dp_fact_cf = [0.9994, 0.9996, 0.9996]

dp_decaf_ftu = [0.9992, 0.9997, 0.9991]
dp_decaf_dp = [0.9992, 0.9993, 0.999]
dp_decaf_cf = [0.9987, 0.9993, 0.9990]

y_label = "Detection: MLP"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %% [markdown]
# **privacy**

# %%
#id score
dp = [0.0036, 0.0141, 0.0061]

dp_fact_ftu = [0.0026, 0.0028, 0.0035]
dp_fact_dp = [0.0104, 0.0189, 0.0366]
dp_fact_cf = [0.0040, 0.0049, 0.0040]

dp_decaf_ftu = [0.0072, 0.0064, 0.0114]
dp_decaf_dp = [0.0071, 0.0114, 0.0126]
dp_decaf_cf = [0.0153, 0.0049, 0.0126]

y_label = "Identification Score"
plt.plot(eps, dp, "-*", markersize=15, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()

# %%
# MIA _accuracy
dp = [0.4999, 0.4999, 0.5000]

dp_fact_ftu = [0.5, 0.4999, 0.5]
dp_fact_dp = [0.5000, 0.5000, 0.4999]
dp_fact_cf = [0.4999, 0.5, 0.4999]

y_label = "Membership Inference Attack: Accuracy"
plt.plot(eps, dp, "-*", markersize=17, label = "dpgan")
plt.plot(eps, dp_fact_cf, "-o", markersize=6, label = "dpgan_fact_cf")
plt.plot(eps, dp_fact_dp, "-o", markersize=8, label = "dpgan_fact_dp")
plt.plot(eps, dp_fact_ftu, "-o", markersize=11, label = "dpgan_fact_ftu")
# plt.plot(eps, dp_decaf_ftu, "-s", markersize=6, label = "dpgan_decaf_ftu")
# plt.plot(eps, dp_decaf_dp, "-s", markersize=8, label = "dpgan_decaf_dp")
# plt.plot(eps, dp_decaf_cf, "-s", markersize=11, label = "dpgan_decaf_cf")
plt.xlabel("Privacy Budget")
plt.ylabel(y_label)
plt.legend()
plt.show()
#didn't run for decaf
# dp_decaf_ftu = []
# dp_decaf_dp = []
# dp_decaf_cf = []
